# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# %%
# generate the data using make_blods(cluster_2.7 sample 500)
features, true_labes = make_blobs(n_samples = 500, cluster_std = 2.7, centers= 20)

# %%
# Printing five elements for each of the variable returned by make_blobs.
print(features[:5])
print(true_labes[:5])
# Out:
# [[  4.10344627  -4.67344881]
#  [ -1.72519392   9.8788859 ]
#  [  7.33819029  -9.71783694]
#  [ -6.47707867 -11.97449954]
#  [  1.65886478  -4.59381177]]
# [ 6 15  9 14  8]

# %%
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)
print(scaled_features[:5])
kmeans = KMeans(init="random", n_clusters=20, n_init= 10, max_iter= 300, random_state=42)
# Out:
# [[ 0.40227199 -0.65697912]
#  [-0.47937313  1.6239159 ]
#  [ 0.89156215 -1.44762337]
#  [-1.19814729 -1.80132679]
#  [ 0.03250249 -0.64449702]]

# %%
kmeans = KMeans(init="random", n_clusters=20, n_init= 10, max_iter= 300, random_state=42)
kmeans.fit(scaled_features)
# Out:
# KMeans(init='random', n_clusters=20, random_state=42)

# %%
kmeans.inertia_
# Out:
# 55.706668593702425

# %%
# Running elbow method to find a appropiate number of clusters

kmean_kwargs = {"init":"random","n_init":10,"max_iter":300, "random_state":42}

#Create empty list to hold the SSE for each k
number_of_cluster = 20
sse = []
for k in range(1,number_of_cluster):
    kmeans = KMeans(n_clusters=k,**kmean_kwargs)
    kmeans.fit(scaled_features)
    sse.append(kmeans.inertia_)

# %%
plt.style.use("fivethirtyeight")
plt.plot(range(1,number_of_cluster),sse)
plt.xticks(range(1,number_of_cluster))
plt.xlabel("Number of clusters")
plt.ylabel("SSE")
print(sse[18])
# Out:
# 58.119925569822726

# %%
# generate the data using make_blods(cluster_std=3 n_sample=500)
features, true_labes = make_blobs(n_samples = 500, cluster_std = 3, centers= 20)

# %%
print(features[:5])
print(true_labes[:5])
# Out:
# [[  3.92045745  -3.37213168]
#  [  1.41413027 -13.36574902]
#  [  6.73512853  -6.23996764]
#  [  3.35297635  -9.91094456]
#  [  2.17414261  -6.58973546]]
# [8 1 9 8 9]

# %%
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)
print(scaled_features[:5])
kmeans = KMeans(init="random", n_clusters=20, n_init= 10, max_iter= 300, random_state=42)
# Out:
# [[ 1.08231913 -0.54910464]
#  [ 0.70072852 -1.85693912]
#  [ 1.51085539 -0.92440966]
#  [ 0.99591962 -1.40481931]
#  [ 0.8164411  -0.97018272]]

# %%
kmeans.fit(scaled_features)
# Out:
# KMeans(init='random', n_clusters=20, random_state=42)

# %%
kmeans.inertia_
# Out:
# 52.38269122326723

# %%
 # Running elbow method to find a appropiate number of clusters

kmean_kwargs = {"init":"random","n_init":10,"max_iter":300, "random_state":42}

#Create empty list to hold the SSE for each k
number_of_cluster = 20
sse = []
for k in range(1,number_of_cluster):
    kmeans = KMeans(n_clusters=k,**kmean_kwargs)
    kmeans.fit(scaled_features)
    sse.append(kmeans.inertia_)

# %%
# generate the data using make_blods(cluster_5, 50 clusters)
features, true_labes = make_blobs(n_samples = 500, cluster_std = 5, centers= 3)

# %%
print(features[:5])
print(true_labes[:5])
# Out:
# [[  0.4202737   -3.44809596]
#  [ -3.83749238  10.11427271]
#  [ -3.68234485   3.32904475]
#  [-10.17140607   7.18014491]
#  [-10.52875227   9.29677123]]
# [2 2 2 1 1]

# %%
kmeans.fit(scaled_features)
# Out:
# KMeans(init='random', n_clusters=19, random_state=42)

# %%
kmeans.inertia_
# Out:
# 54.60410039111042

# %%
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)
print(scaled_features[:5])
kmeans = KMeans(init="random", n_clusters=50, n_init= 10, max_iter= 300, random_state=42)
# Out:
# [[-0.05486405 -1.23423776]
#  [-0.49911605  0.99901329]
#  [-0.48292808 -0.11827808]
#  [-1.15999169  0.51586436]
#  [-1.19727691  0.8643992 ]]

# %%
# Running elbow method to find a appropiate number of clusters

kmean_kwargs = {"init":"random","n_init":10,"max_iter":300, "random_state":42}

#Create empty list to hold the SSE for each k
number_of_cluster = 50
sse = []
for k in range(1,number_of_cluster):
    kmeans = KMeans(n_clusters=k,**kmean_kwargs)
    kmeans.fit(scaled_features)
    sse.append(kmeans.inertia_)

# %%
plt.figure(figsize=(40,20))
plt.style.use("fivethirtyeight")
plt.plot(range(1,number_of_cluster),sse)
plt.xticks(range(1,number_of_cluster))
plt.xlabel("Number of clusters")
plt.ylabel("SSE")
print(sse[18])
# Out:
# 67.3151835985229

# %%
# generate the data using make_blods(cluster_9, 50 clusters)
features, true_labes = make_blobs(n_samples = 500, cluster_std = 9, centers= 3)

# %%
print(features[:5])
print(true_labes[:5])
# Out:
# [[ -6.87446537   6.53882356]
#  [ -3.88512325  -9.53841246]
#  [  7.02132668 -12.30185516]
#  [-20.34109259  16.12066639]
#  [ -4.37059433 -10.25479405]]
# [1 2 2 1 2]

# %%
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)
print(scaled_features[:5])
kmeans = KMeans(init="random", n_clusters=50, n_init= 10, max_iter= 300, random_state=42)
# Out:
# [[-0.26378974  0.90329877]
#  [ 0.04576043 -0.59176097]
#  [ 1.17513715 -0.84873996]
#  [-1.65827607  1.79433672]
#  [-0.00451072 -0.65837897]]

# %%
kmeans.fit(scaled_features)
# Out:
# KMeans(init='random', n_clusters=50, random_state=42)

# %%
# Running elbow method to find a appropiate number of clusters

kmean_kwargs = {"init":"random","n_init":10,"max_iter":300, "random_state":42}

#Create empty list to hold the SSE for each k
number_of_cluster = 50
sse = []
for k in range(1,number_of_cluster):
    kmeans = KMeans(n_clusters=k,**kmean_kwargs)
    kmeans.fit(scaled_features)
    sse.append(kmeans.inertia_)

# %%
plt.style.use("fivethirtyeight")
plt.plot(range(1,number_of_cluster),sse)
plt.xticks(range(1,number_of_cluster))
plt.xlabel("Number of clusters")
plt.ylabel("SSE")
print(sse[18])
# Out:
# 75.73337909831895
